# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("FBPres.csv")
df2 = pd.read_csv("Alan.csv")
df2 = df2.fillna(0)
df = df.fillna(0)

df.head()
# Out:
#    ID             Datetime  Year  Month  Day   FB
# 0   0  2009-07-09 20:01:00  2009      7    9  0.0
# 1   1  2009-07-13 18:20:00  2009      7   13  0.0
# 2   2  2009-07-09 20:01:00  2009      7    9  0.0
# 3   3  2009-07-13 18:20:00  2009      7   13  0.0
# 4   4  2010-04-05 17:50:00  2010      4    5  0.0

# %%
sns.pairplot(data = df, hue = 'FB')

# %%
sns.histplot(data=df, x="Year", hue = 'FB')
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
sns.histplot(data=df, x="Month", hue = 'FB')
# Out:
# <Axes: xlabel='Month', ylabel='Count'>

# %%
sns.histplot(data=df, x="Day", hue = 'FB')
# Out:
# <Axes: xlabel='Day', ylabel='Count'>

# %%
# sns.histplot(data=df2, x="SZA", hue = "Labels")
# sns.pairplot(df2)

# %%
# sns.pairplot(data = df2, hue = 'Labels')

# %%
df3 = pd.read_csv("Alan.csv")
df3 = df3.dropna()
df3.head
# Out:
# <bound method NDFrame.head of          Unnamed: 0             Date_UTC  dbn_nez  dbe_nez  dbz_nez     SZA  \
# 0                 0  2009-01-01T00:00:00      5.1    -16.8    -12.4  110.65
# 1                 1  2009-01-01T00:01:00      5.1    -16.8    -12.4  110.71
# 2                 2  2009-01-01T00:02:00      6.4    -17.2    -11.4  110.78
# 3                 3  2009-01-01T00:03:00      5.9    -16.4    -10.4  110.84
# 4                 4  2009-01-01T00:04:00      6.3    -15.1    -10.4  110.91
# ...             ...                  ...      ...      ...      ...     ...
# 7629116     7629116  2022-07-04T23:56:00     41.2    -12.4    -16.4   66.20
# 7629117     7629117  2022-07-04T23:57:00     42.4    -12.9    -16.0   66.26
# 7629118     7629118  2022-07-04T23:58:00     43.1    -15.2    -16.6   66.33
# 7629119     7629119  2022-07-04T23:59:00     41.5    -18.4    -18.5   66.39
# 7629120     7629120  2022-07-05T00:00:00     39.1    -21.8    -20.5   66.46
#
#          Labels
# ...

# %%
import random
# dropindices = np.random.choice(df[df['Labels'] == 0].index.tolist(), size = int(df.shape[0]))
dropindices = df3[df3['Labels'] == 0].index.tolist()
dropindices = random.sample(dropindices, int(len(dropindices) * 0.995))
df3 = df3.drop(dropindices)

# %%
sns.histplot(data=df3, x="SZA", hue="Labels")
# Out:
# <Axes: xlabel='SZA', ylabel='Count'>
