# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from pandas.api.types import is_string_dtype, is_numeric_dtype
import random
import scipy
from scipy.stats import ttest_ind

# %%
df = pd.read_csv('FullDataset.csv',usecols=['Date','BZ_North','Magnetometer_Magnitude','Magnetometer_Theta','Magnetometer_Phi','Velocity_Latitude_n/s','Velocity_Latitude_e/w','Labels'])
df = df[21100:26856]
df_3_1 = df[0:2878]
df_3_2 = df[0:-2878]

# %%
# fig,axarr = plt.subplots(3,1,sharex=True,figsize=(15, 10))
# axarr[0].plot(df_3_1['BZ_North'])
# axarr[0].plot(df_3_1['Magnetometer_Magnitude'])
# axarr[1].plot(df_3_1['BZ_North'])
# axarr[1].plot(df_3_1['Velocity_Latitude_n/s'])
# axarr[2].plot(df_3_1['BZ_North'])
# axarr[2].plot(df_3_1['Velocity_Latitude_e/w'])

# %% [markdown]
# # First 3 hours of 2016-08-02

# %%
fig,axarr = plt.subplots(3,1,sharex=True,figsize=(15, 10))
fig.suptitle('2016-08-02 00:00 to 02:59', fontsize=20)

axarr[0].plot(df_3_1['BZ_North'],label="BZ_North")
axarr[0].set_title('BZ_North vs Magnetometer_Magnitude')
ax2 = axarr[0].twinx()
ax2.set_ylabel('nT')
ax2.plot(df_3_1['Magnetometer_Magnitude'],label="Magnetometer Magnitude", color = 'orange')
ax2.legend()
axarr[0].set_ylabel('nT')
axarr[0].legend(loc=2)

axarr[1].plot(df_3_1['BZ_North'],label="BZ_North")
axarr[1].set_title('BZ_North vs Velocity_Latitude_n/s')
ax2 = axarr[1].twinx()
ax2.set_ylabel('m/s')
ax2.plot(df_3_1['Velocity_Latitude_n/s'],label="VLat N/S", color = 'orange')
ax2.legend()
axarr[1].set_ylabel('nT')
axarr[1].legend(loc=2)

axarr[2].plot(df_3_1['BZ_North'],label="BZ_North")
axarr[2].set_title('BZ_North vs Velocity_Latitude_e/w')
axarr[2].set_xlabel('Index ~1000 per hour')
ax2 = axarr[2].twinx()
ax2.set_ylabel('m/s')
ax2.plot(df_3_1['Velocity_Latitude_e/w'],label="VLat E/W", color = 'orange')
ax2.legend()
axarr[2].set_ylabel('nT')
axarr[2].legend(loc=2)

# %%
fig,axarr = plt.subplots(3,1,sharex=True,figsize=(15, 10))
fig.suptitle('2016-08-02 00:00 to 02:59', fontsize=20)

axarr[0].plot(df_3_1['Magnetometer_Magnitude'],label="Magnetometer_Magnitude")
axarr[0].set_title('Magnetometer_Magnitude vs BZ_North')
ax2 = axarr[0].twinx()
ax2.set_ylabel('nT')
ax2.plot(df_3_1['BZ_North'],label="BZ_North", color = 'orange')
ax2.legend()
axarr[0].set_ylabel('nT')
axarr[0].legend(loc=2)

axarr[1].plot(df_3_1['Magnetometer_Magnitude'],label="Magnetometer_Magnitude")
axarr[1].set_title('Magnetometer_Magnitude vs Velocity_Latitude_n/s')
ax2 = axarr[1].twinx()
ax2.set_ylabel('m/s')
ax2.plot(df_3_1['Velocity_Latitude_n/s'],label="VLat N/S", color = 'orange')
ax2.legend()
axarr[1].set_ylabel('nT')
axarr[1].legend(loc=2)

axarr[2].plot(df_3_1['Magnetometer_Magnitude'],label="Magnetometer_Magnitude")
axarr[2].set_title('Magnetometer_Magnitude vs Velocity_Latitude_e/w')
axarr[2].set_xlabel('Index ~1000 per hour')
ax2 = axarr[2].twinx()
ax2.set_ylabel('m/s')
ax2.plot(df_3_1['Velocity_Latitude_e/w'],label="VLat E/W", color='orange')
ax2.legend()
axarr[2].set_ylabel('nT')
axarr[2].legend(loc=2)

# %%
fig,axarr = plt.subplots(3,1,sharex=True,figsize=(15, 10))
fig.suptitle('2016-08-02 00:00 to 02:59', fontsize=20)

axarr[0].plot(df_3_1['Velocity_Latitude_n/s'],label="VLat N/S")
axarr[0].set_title('Velocity_Latitude_n/s vs BZ_North')
ax2 = axarr[0].twinx()
ax2.set_ylabel('nT')
ax2.plot(df_3_1['BZ_North'],label="BZ_North", color = 'orange')
ax2.legend()
axarr[0].set_ylabel('m/s')
axarr[0].legend(loc=2)

axarr[1].plot(df_3_1['Velocity_Latitude_n/s'],label="VLat N/S")
axarr[1].set_title('Velocity_Latitude_n/s vs Magnetometer_Magnitude')
ax2 = axarr[1].twinx()
ax2.set_ylabel('nT')
ax2.plot(df_3_1['Magnetometer_Magnitude'],label="Magnetometer_Magnitude", color = 'orange')
ax2.legend()
axarr[1].set_ylabel('m/s')
axarr[1].legend(loc=2)

axarr[2].plot(df_3_1['Velocity_Latitude_n/s'],label="VLat N/S")
axarr[2].set_title('Velocity_Latitude_n/s vs Velocity_Latitude_e/w')
axarr[2].set_xlabel('Index ~1000 per hour')
ax2 = axarr[2].twinx()
ax2.set_ylabel('m/s')
ax2.plot(df_3_1['Velocity_Latitude_e/w'],label="VLat E/W", color = 'orange')
ax2.legend()
axarr[2].set_ylabel('m/s')
axarr[2].legend(loc=2)

# %%
fig,axarr = plt.subplots(3,1,sharex=True,figsize=(15, 10))
fig.suptitle('2016-08-02 00:00 to 02:59', fontsize=20)

axarr[0].plot(df_3_1['Velocity_Latitude_e/w'],label="VLat E/W")
axarr[0].set_title('Velocity_Latitude_e/w vs BZ_North')
ax2 = axarr[0].twinx()
ax2.set_ylabel('nT')
ax2.plot(df_3_1['BZ_North'],label="BZ_North", color = 'orange')
ax2.legend()
axarr[0].set_ylabel('m/s')
axarr[0].legend(loc=2)

axarr[1].plot(df_3_1['Velocity_Latitude_e/w'],label="VLat E/W")
axarr[1].set_title('Velocity_Latitude_e/w vs Magnetometer_Magnitude')
ax2 = axarr[1].twinx()
ax2.set_ylabel('nT')
ax2.plot(df_3_1['Magnetometer_Magnitude'],label="Magnetometer_Magnitude", color = 'orange')
ax2.legend()
axarr[1].set_ylabel('m/s')
axarr[1].legend(loc=2)

axarr[2].plot(df_3_1['Velocity_Latitude_e/w'],label="VLat E/W")
axarr[2].set_title('Velocity_Latitude_e/w vs Velocity_Latitude_n/s')
axarr[2].set_xlabel('Index ~1000 per hour')
ax2 = axarr[2].twinx()
ax2.set_ylabel('m/s')
ax2.plot(df_3_1['Velocity_Latitude_n/s'],label="VLat N/S", color = 'orange')
ax2.legend()
axarr[2].set_ylabel('m/s')
axarr[2].legend(loc=2)

# %% [markdown]
# # Second 3 hours of 2016-08-02

# %%
fig,axarr = plt.subplots(3,1,sharex=True,figsize=(15, 10))
fig.suptitle('2016-08-02 03:00 to 05:59', fontsize=20)

axarr[0].plot(df_3_2['BZ_North'],label="BZ_North")
axarr[0].set_title('BZ_North vs Magnetometer_Magnitude')
ax2 = axarr[0].twinx()
ax2.set_ylabel('nT')
ax2.plot(df_3_2['Magnetometer_Magnitude'],label="Magnetometer Magnitude", color = 'orange')
ax2.legend()
axarr[0].set_ylabel('nT')
axarr[0].legend(loc=2)

axarr[1].plot(df_3_2['BZ_North'],label="BZ_North")
axarr[1].set_title('BZ_North vs Velocity_Latitude_n/s')
ax2 = axarr[1].twinx()
ax2.set_ylabel('m/s')
ax2.plot(df_3_2['Velocity_Latitude_n/s'],label="VLat N/S", color = 'orange')
ax2.legend()
axarr[1].set_ylabel('nT')
axarr[1].legend(loc=2)

axarr[2].plot(df_3_2['BZ_North'],label="BZ_North")
axarr[2].set_title('BZ_North vs Velocity_Latitude_e/w')
axarr[2].set_xlabel('Index ~1000 per hour')
ax2 = axarr[2].twinx()
ax2.set_ylabel('m/s')
ax2.plot(df_3_2['Velocity_Latitude_e/w'],label="VLat E/W", color = 'orange')
ax2.legend()
axarr[2].set_ylabel('nT')
axarr[2].legend(loc=2)

# %%
fig,axarr = plt.subplots(3,1,sharex=True,figsize=(15, 10))
fig.suptitle('2016-08-02 03:00 to 05:59', fontsize=20)

axarr[0].plot(df_3_2['Magnetometer_Magnitude'],label="Magnetometer_Magnitude")
axarr[0].set_title('Magnetometer_Magnitude vs BZ_North')
ax2 = axarr[0].twinx()
ax2.set_ylabel('nT')
ax2.plot(df_3_2['BZ_North'],label="BZ_North", color = 'orange')
ax2.legend()
axarr[0].set_ylabel('nT')
axarr[0].legend(loc=2)

axarr[1].plot(df_3_2['Magnetometer_Magnitude'],label="Magnetometer_Magnitude")
axarr[1].set_title('Magnetometer_Magnitude vs Velocity_Latitude_n/s')
ax2 = axarr[1].twinx()
ax2.set_ylabel('m/s')
ax2.plot(df_3_2['Velocity_Latitude_n/s'],label="VLat N/S", color = 'orange')
ax2.legend()
axarr[1].set_ylabel('nT')
axarr[1].legend(loc=2)

axarr[2].plot(df_3_2['Magnetometer_Magnitude'],label="Magnetometer_Magnitude")
axarr[2].set_title('Magnetometer_Magnitude vs Velocity_Latitude_e/w')
axarr[2].set_xlabel('Index ~1000 per hour')
ax2 = axarr[2].twinx()
ax2.set_ylabel('m/s')
ax2.plot(df_3_2['Velocity_Latitude_e/w'],label="VLat E/W", color='orange')
ax2.legend()
axarr[2].set_ylabel('nT')
axarr[2].legend(loc=2)

# %%
fig,axarr = plt.subplots(3,1,sharex=True,figsize=(15, 10))
fig.suptitle('2016-08-02 03:00 to 05:59', fontsize=20)

axarr[0].plot(df_3_2['Velocity_Latitude_n/s'],label="VLat N/S")
axarr[0].set_title('Velocity_Latitude_n/s vs BZ_North')
ax2 = axarr[0].twinx()
ax2.set_ylabel('nT')
ax2.plot(df_3_2['BZ_North'],label="BZ_North", color = 'orange')
ax2.legend()
axarr[0].set_ylabel('m/s')
axarr[0].legend(loc=2)

axarr[1].plot(df_3_2['Velocity_Latitude_n/s'],label="VLat N/S")
axarr[1].set_title('Velocity_Latitude_n/s vs Magnetometer_Magnitude')
ax2 = axarr[1].twinx()
ax2.set_ylabel('nT')
ax2.plot(df_3_2['Magnetometer_Magnitude'],label="Magnetometer_Magnitude", color = 'orange')
ax2.legend()
axarr[1].set_ylabel('m/s')
axarr[1].legend(loc=2)

axarr[2].plot(df_3_2['Velocity_Latitude_n/s'],label="VLat N/S")
axarr[2].set_title('Velocity_Latitude_n/s vs Velocity_Latitude_e/w')
axarr[2].set_xlabel('Index ~1000 per hour')
ax2 = axarr[2].twinx()
ax2.set_ylabel('m/s')
ax2.plot(df_3_2['Velocity_Latitude_e/w'],label="VLat E/W", color = 'orange')
ax2.legend()
axarr[2].set_ylabel('m/s')
axarr[2].legend(loc=2)

# %%
fig,axarr = plt.subplots(3,1,sharex=True,figsize=(15, 10))
fig.suptitle('2016-08-02 03:00 to 05:59', fontsize=20)

axarr[0].plot(df_3_2['Velocity_Latitude_e/w'],label="VLat E/W")
axarr[0].set_title('Velocity_Latitude_e/w vs BZ_North')
ax2 = axarr[0].twinx()
ax2.set_ylabel('nT')
ax2.plot(df_3_2['BZ_North'],label="BZ_North", color = 'orange')
ax2.legend()
axarr[0].set_ylabel('m/s')
axarr[0].legend(loc=2)

axarr[1].plot(df_3_2['Velocity_Latitude_e/w'],label="VLat E/W")
axarr[1].set_title('Velocity_Latitude_e/w vs Magnetometer_Magnitude')
ax2 = axarr[1].twinx()
ax2.set_ylabel('nT')
ax2.plot(df_3_2['Magnetometer_Magnitude'],label="Magnetometer_Magnitude", color = 'orange')
ax2.legend()
axarr[1].set_ylabel('m/s')
axarr[1].legend(loc=2)

axarr[2].plot(df_3_2['Velocity_Latitude_e/w'],label="VLat E/W")
axarr[2].set_title('Velocity_Latitude_e/w vs Velocity_Latitude_n/s')
axarr[2].set_xlabel('Index ~1000 per hour')
ax2 = axarr[2].twinx()
ax2.set_ylabel('m/s')
ax2.plot(df_3_2['Velocity_Latitude_n/s'],label="VLat N/S", color = 'orange')
ax2.legend()
axarr[2].set_ylabel('m/s')
axarr[2].legend(loc=2)

# %%
# fig,axarr = plt.subplots(4,1,sharex=True,figsize=(15, 10))
# sns.scatterplot(ax=axarr[0],data=df_3_1,x='Date',y='BZ_North',hue='Labels')
# sns.scatterplot(ax=axarr[1],data=df_3_1,x='Date',y='Magnetometer_Magnitude',hue='Labels')
# sns.scatterplot(ax=axarr[2],data=df_3_1,x='Date',y='Velocity_Latitude_n/s',hue='Labels')
# sns.scatterplot(ax=axarr[3],data=df_3_2,x='Date',y='Velocity_Latitude_e/w',hue='Labels')

# %%
# fig,axarr = plt.subplots(4,1,sharex=True,figsize=(15, 10))
# sns.scatterplot(ax=axarr[0],data=df_3_2,x='Date',y='BZ_North',hue='Labels')
# sns.scatterplot(ax=axarr[1],data=df_3_2,x='Date',y='Magnetometer_Magnitude',hue='Labels')
# sns.scatterplot(ax=axarr[2],data=df_3_2,x='Date',y='Velocity_Latitude_n/s',hue='Labels')
# sns.scatterplot(ax=axarr[3],data=df_3_2,x='Date',y='Velocity_Latitude_e/w',hue='Labels')
